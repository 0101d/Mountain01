# %%
#本部分调研搜索界面的第2页
#调用requetss包请求网页源代码
import requests
from bs4 import BeautifulSoup
from bs4 import element
import csv
#本次抽样百分之一，185份样品，只选取8页
#本次直接爬取了从0到144页面的所有相应信息，将信息保存在csv格式文件之中

#以下是csv转换区，提前做好csv表格准备
csv_file = open('TimonAll.csv','w',encoding="gbk",newline='')
writer = csv.writer(csv_file)
writer.writerow(["艺术家","热度"])#编辑表格中的标题

for i in range(0,8):
    print(i)#这里用来验证页数是否正常
    icount = i*24
    url = "https://www.deviantart.com/popular-all-time/?section=&global=1&q=Timon&offset="+str(icount)
    response = requests.get(url)
    #print(response.content.decode('utf-8'))

    #将网页源代码保存到本地MyBambi.html文件中
    file_obj = open('MyTimonAll.html','w')
    file_obj.write(response.content.decode('utf-8'))
    file_obj.close()

    #从bs4引入数据提取工具BeautifulSoup
    from bs4 import BeautifulSoup
    file_obj = open('MyTimonAll.html','r')#以读方式打开MyBambi文件
    html = file_obj.read() #把文件的内容全部读出来并赋值给html变量
    file_obj.close()
    soup = BeautifulSoup(html,'html5lib')#html.parser,html5lib初始化BeautifulSoup，使用lxml有可能会有格式问题
    #print(soup)#输出BeautifulSoup转换后 的源代码内容

    #all_bambis = soup.find('div',class_="page-results results-page-thumb torpedo-container torpedo-container-xs")
    all_bambis = soup.find('div',class_="browse-content with-sidemenu") #先找到所有bambi作品所在的最大div
    #print(all_bambis) #输出该范围的所有内容

    #注意：csv转换区！
   # csv_file = open('BambiPageAll.csv','w',encoding="gbk",newline='')
   # writer = csv.writer(csv_file)

    #writer.writerow(["艺术家","热度"])#写入标题
    #csv转换块暂时结束

    #一下是在先前程序测试后排出标签异常页的更新
    
    #if( i!=9 and i!=16 and i!=17):
    for each_bambi in all_bambis.find_all('span',class_="info"):
            all_a_tag = each_bambi.find_all('a')
            all_hot_tag = each_bambi.find_all('span',class_="faves icon-faves")
            #bambi_artist = all_a_tag[1].text
            #bambi_hot = all_hot_tag[0].text
            #print("'a'标签个数=", len(all_a_tag))
            #print("热度所在标签",len(all_hot_tag))
            
            if(len(all_a_tag)==2 and len(all_hot_tag)==1):
                bambi_artist = all_a_tag[1].text
                bambi_hot = all_hot_tag[0].text
            #print(len(all_a_tag))#检测两个标签的数量是否符合平常数值
            #print(len(all_hot_tag))
                print('艺术家:{},热度:{}'.format(bambi_artist,bambi_hot))
                writer.writerow([bambi_artist,bambi_hot])

csv_file.close()
    #print("write_finished!")
# Out:
# 0
# 艺术家:ShakShakalut,热度:134
# 艺术家:Tiamat17,热度:126
# 艺术家:kh27s,热度:710
# 艺术家:Mareishon,热度:202
# 艺术家:Gilligan-Stamps,热度:143
# 艺术家:Velvet-Loz,热度:170
# 艺术家:LobbyLane,热度:132
# 艺术家:seles66,热度:121
# 艺术家:SHWZ,热度:88
# 艺术家:sinsenor,热度:469
# 艺术家:gooseberry007,热度:299
# 艺术家:Anika83,热度:180
# 艺术家:DolphyDolphiana,热度:958
# 艺术家:Raygirl13,热度:446
# 艺术家:joshuadraws,热度:64
# 艺术家:Konyhyuga-sama,热度:94
# 艺术家:katikat,热度:62
# 艺术家:kati-kopa,热度:74
# 艺术家:AtomiccircuS,热度:634
# 艺术家:Credens-Vita,热度:184
# 艺术家:dapumakat,热度:29
# 艺术家:Jose-Ramiro,热度:54
# 艺术家:Credens-Vita,热度:174
# 艺术家:AllesiaTheHedge,热度:91
# 艺术家:HermioneFrost,热度:34
# 艺术家:LauzLanille,热度:74
# 艺术家:AlPendragon,热度:70
# 艺术家:Zheltkevich,热度:98
# 艺术家:dapumakat,热度:29
# 艺术家:The-Waffle-Child,热度:124
# 艺术家:Credens-Vita,热度:135
# 5
# 艺术家:megachaos,热度:123
# 艺术家:DiHA-Artwork,热度:38
# 艺术家:Chibi-N92,热度:152
# 艺术家:chocolatecherry,热度:181
# 艺术家:Mirinata,热度:76
# 艺术家:CaptainEdwardTeague,热度:92
# 艺术家:keep-me-posted,热度:136
# 艺术家:GloriosusPugnator,热度:141
# 艺术家:Starfig,热度:183
# 艺术家:Nollaig,热度:172
# 艺术家:Snowflake-owl,热度:75
# 艺术家:Nikki-Rose,热度:48
# 艺术家:AnutDraws,热度:81
# 艺术家:roney2011,热度:78
# 艺术家:chees-dobles,热度:25
# 艺术家:JR-Style,热度:185
# 艺术家:Verusca,热度:183
# 艺术家:Credens-Vita,热度:215
# 艺术家:CaptainEdwardTeague,热度:75
# 艺术家:Credens-Vita,热度:144
# 艺术家:Mancoin,热度:174
# 艺术家:MixelFanGirl100,热度:18
# 艺术家:Rapunzel-Magic-Frost,热度:106
# 6
# 艺术家:brown2002,热度:63
# 艺术家:TwilightProwler,热度:869
# 艺术家:LobaFeroz,热度:110
# 艺术家:BlueprintPredator,热度:30
# 艺术家:theEyZmaster,热度:147
# 艺术家:Stitchfan,热度:77
# 艺术家:dexikon,热度:120
# 艺术家:Credens-Vita,热度:127
# 艺术家:dapumakat,热度:19
# 艺术家:TwilightProwler,热度:289
# 艺术家:hazumonster,热度:55
# 艺术家:eagc7,热度:131
# 艺术家:unitedcba,热度:36
# 艺术家:Fairloke,热度:98
# 艺术家:dapumakat,热度:21
# 艺术家:WereMorta,热度:54
# 艺术家:Credens-Vita,热度:202
# 艺术家:SithVampireMaster27,热度:41
# 艺术家:WoW-200,热度:67
# 艺术家:rulerofthepridelands,热度:20
# 艺术家:NyotLeo,热度:111
# 艺术家:alucardserasfangirl,热度:128
# 7
# 艺术家:BrainyxBat,热度:51
# 艺术家:Enricthepenguin92,热度:60
# 艺术家:SuperMarioFan65,热度:12
# 艺术家:Sandkingart,热度:53
# 艺术家:TrishaKat,热度:28
# 艺术家:NyotLeo,热度:68
# 艺术家:avispaneitor,热度:52
# 艺术家:BrunoMilan13,热度:24
# 艺术家:theEyZmaster,热度:130
# 艺术家:RogersGirlRabbit,热度:72
# 艺术家:KimDingwall,热度:47
# 艺术家:AmBr0,热度:64
# 艺术家:strange-fiction,热度:50
# 艺术家:RetroUniverseArt,热度:29
# 艺术家:Heliocathus,热度:39
# 艺术家:BrainyxBat,热度:19
# 艺术家:knuFaD-zzaJ,热度:101
# 艺术家:almostkilledme,热度:81
# 艺术家:funnytime77,热度:59
# 艺术家:theHyenasSBE,热度:46
# 艺术家:knuFaD-zzaJ,热度:95
