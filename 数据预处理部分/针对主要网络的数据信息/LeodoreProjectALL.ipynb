# %%
#本部分调研搜索界面的第2页
#调用requetss包请求网页源代码
import requests
from bs4 import BeautifulSoup
from bs4 import element
import csv
#本次抽样百分之一，39份样品，1个页面
#本次不抽样161份样品，总共5个页面
#本次直接爬取了从0到144页面的所有相应信息，将信息保存在csv格式文件之中

#以下是csv转换区，提前做好csv表格准备
csv_file = open('LeodoreAll.csv','w',encoding="gbk",newline='')
writer = csv.writer(csv_file)
writer.writerow(["艺术家","热度"])#编辑表格中的标题

for i in range(0,5):
    print(i)#这里用来验证页数是否正常
    icount = i*24
    url = "https://www.deviantart.com/popular-all-time/?section=&global=1&q=Leodore&offset="+str(icount)
    response = requests.get(url)
    #print(response.content.decode('utf-8'))

    #将网页源代码保存到本地MyBambi.html文件中
    file_obj = open('MyLeodoreAll.html','w')
    file_obj.write(response.content.decode('utf-8'))
    file_obj.close()

    #从bs4引入数据提取工具BeautifulSoup
    from bs4 import BeautifulSoup
    file_obj = open('MyLeodoreAll.html','r')#以读方式打开MyBambi文件
    html = file_obj.read() #把文件的内容全部读出来并赋值给html变量
    file_obj.close()
    soup = BeautifulSoup(html,'html5lib')#html.parser,html5lib初始化BeautifulSoup，使用lxml有可能会有格式问题
    #print(soup)#输出BeautifulSoup转换后 的源代码内容

    #all_bambis = soup.find('div',class_="page-results results-page-thumb torpedo-container torpedo-container-xs")
    all_bambis = soup.find('div',class_="browse-content with-sidemenu") #先找到所有bambi作品所在的最大div
    #print(all_bambis) #输出该范围的所有内容

    #注意：csv转换区！
   # csv_file = open('BambiPageAll.csv','w',encoding="gbk",newline='')
   # writer = csv.writer(csv_file)

    #writer.writerow(["艺术家","热度"])#写入标题
    #csv转换块暂时结束

    #一下是在先前程序测试后排出标签异常页的更新
    
    #if( i!=9 and i!=16 and i!=17):
    for each_bambi in all_bambis.find_all('span',class_="info"):
            all_a_tag = each_bambi.find_all('a')
            all_hot_tag = each_bambi.find_all('span',class_="faves icon-faves")
            #bambi_artist = all_a_tag[1].text
            #bambi_hot = all_hot_tag[0].text
            #print("'a'标签个数=", len(all_a_tag))
            #print("热度所在标签",len(all_hot_tag))
            
            if(len(all_a_tag)==2 and len(all_hot_tag)==1):
                bambi_artist = all_a_tag[1].text
                bambi_hot = all_hot_tag[0].text
            #print(len(all_a_tag))#检测两个标签的数量是否符合平常数值
            #print(len(all_hot_tag))
                print('艺术家:{},热度:{}'.format(bambi_artist,bambi_hot))
                writer.writerow([bambi_artist,bambi_hot])

csv_file.close()
    #print("write_finished!")
# Out:
# 0
# 艺术家:Defago,热度:177
# 艺术家:GiuseppeDiRosso,热度:81
# 艺术家:krukof2,热度:34
# 艺术家:krukof2,热度:13
# 艺术家:Ricurd,热度:49
# 艺术家:animatedartlover,热度:66
# 艺术家:JackOrJohn,热度:86
# 艺术家:bullpoopsniperrifle,热度:83
# 艺术家:Jessica-Rae-3,热度:95
# 艺术家:TargonRedDragon,热度:40
# 艺术家:Sketch-Shepherd,热度:181
# 艺术家:pezzimizt,热度:42
# 艺术家:Leonheart27,热度:40
# 艺术家:TheWyvernsWeaver,热度:157
# 艺术家:nmaki98,热度:15
# 艺术家:AleineRoe,热度:128
# 艺术家:Tsukiiyo,热度:14
# 艺术家:AdvanceArcy,热度:41
# 艺术家:HavocDusk,热度:56
# 艺术家:RomainBowen,热度:13
# 艺术家:Codetski101,热度:9
# 1
# 艺术家:Technical-Error,热度:6
# 艺术家:LionKingRulez,热度:5
# 艺术家:Lord-Sagoth,热度:3
# 艺术家:Leonheart27,热度:21
# 艺术家:Rex-equinox,热度:62
# 艺术家:Rex-equinox,热度:58
# 艺术家:Rex-equinox,热度:55
# 艺术家:Rex-equinox,热度:56
# 艺术家:LordWobbler,热度:3
# 艺术家:Rex-equinox,热度:56
# 艺术家:Rex-equinox,热度:56
# 艺术家:Rex-equinox,热度:55
# 艺术家:1AutumnWalker,热度:4
# 艺术家:Lord-Sagoth,热度:2
# 艺术家:ANIMAfelis,热度:5
# 艺术家:hasha92,热度:5
# 艺术家:Whatijustdidnow,热度:7
# 艺术家:FriendshipFan1996,热度:3
# 艺术家:Lord-Sagoth,热度:2
# 艺术家:nmaki98,热度:5
# 2
# 艺术家:YoursLoi06,热度:1
# 艺术家:FriendshipFan1996,热度:4
# 艺术家:hanybony1614,热度:1
# 艺术家:Jeffyraccoon,热度:1
# 艺术家:elzataerinn,热度:10
# 艺术家:Miaoooou,热度:1
# 艺术家:Tima25478,热度:1
# 艺术家:lichtningbolt,热度:7
# 艺术家:ekoi1995,热度:9
# 艺术家:Spizzina00,热度:10
# 艺术家:TiElGar,热度:10
# 艺术家:Noghame,热度:1
# 艺术家:BlueDragon1993,热度:4
# 艺术家:Neyebur,热度:30
# 艺术家:TheWarriorDogs,热度:4
# 艺术家:JoyNoBara,热度:1
# 艺术家:Anubis-13,热度:23
# 艺术家:Yukinekocat,热度:16
# 艺术家:Patrysia03,热度:3
# 艺术家:DracoCharizard87,热度:11
# 艺术家:Gojirafan1994,热度:20
# 艺术家:Anubis-13,热度:21
# 3
# 艺术家:Anubis-13,热度:17
# 艺术家:FriendshipFan1996,热度:2
# 艺术家:kanyiko,热度:3
# 艺术家:xXMESFAMICS1572004Xx,热度:2
# 艺术家:Yukinekocat,热度:6
# 艺术家:The-First-Noel,热度:28
# 艺术家:quarz,热度:0
# 艺术家:brazilianferalcat,热度:8
# 艺术家:Yukinekocat,热度:24
# 艺术家:DarkCatTheKhajjit,热度:3
# 艺术家:BlueDragon0812,热度:12
# 艺术家:Yukinekocat,热度:20
# 艺术家:spitzen,热度:33
# 艺术家:Patrysia03,热度:5
# 艺术家:Anubis-13,热度:34
# 艺术家:elzataerinn,热度:12
# 艺术家:TipsyRa1d3n,热度:14
# 艺术家:Negaboss2000,热度:10
# 艺术家:Ezmanify,热度:18
# 艺术家:Disneycow82,热度:48
# 艺术家:Yukinekocat,热度:5
# 4
# 艺术家:Yukinekocat,热度:6
# 艺术家:Wolfboy1020,热度:7
# 艺术家:SofiaBlythe2014,热度:50
# 艺术家:Anubis-13,热度:8
# 艺术家:Anubis-13,热度:5
# 艺术家:Anubis-13,热度:13
# 艺术家:lichtningbolt,热度:11
# 艺术家:RaindropLily,热度:20
# 艺术家:Crossovermaster1,热度:11
# 艺术家:Disneycow82,热度:33
# 艺术家:Noghame,热度:3
# 艺术家:Yukinekocat,热度:23
# 艺术家:Anubis-13,热度:3
# 艺术家:Noghame,热度:3
# 艺术家:BlueHedgehog1997,热度:10
# 艺术家:Noghame,热度:3
# 艺术家:Disneycow82,热度:37
# 艺术家:LucasGodzilla,热度:5
# 艺术家:Tima25478,热度:1
# 艺术家:leothetiger,热度:1
# 艺术家:DracoCharizard87,热度:6
