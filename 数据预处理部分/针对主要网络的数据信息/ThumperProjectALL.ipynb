# %%
#本部分调研搜索界面的第2页
#调用requetss包请求网页源代码
import requests
from bs4 import BeautifulSoup
from bs4 import element
import csv
#本次抽样百分之一，136份样品，7个页面
#本次直接爬取了从0到144页面的所有相应信息，将信息保存在csv格式文件之中

#以下是csv转换区，提前做好csv表格准备
csv_file = open('ThumperAll.csv','w',encoding="gbk",newline='')
writer = csv.writer(csv_file)
writer.writerow(["艺术家","热度"])#编辑表格中的标题

for i in range(0,7):
    print(i)#这里用来验证页数是否正常
    icount = i*24
    url = "https://www.deviantart.com/popular-all-time/?section=&global=1&q=Thumper&offset="+str(icount)
    response = requests.get(url)
    #print(response.content.decode('utf-8'))

    #将网页源代码保存到本地MyBambi.html文件中
    file_obj = open('MyThumperAll.html','w')
    file_obj.write(response.content.decode('utf-8'))
    file_obj.close()

    #从bs4引入数据提取工具BeautifulSoup
    from bs4 import BeautifulSoup
    file_obj = open('MyThumperAll.html','r')#以读方式打开MyBambi文件
    html = file_obj.read() #把文件的内容全部读出来并赋值给html变量
    file_obj.close()
    soup = BeautifulSoup(html,'html5lib')#html.parser,html5lib初始化BeautifulSoup，使用lxml有可能会有格式问题
    #print(soup)#输出BeautifulSoup转换后 的源代码内容

    #all_bambis = soup.find('div',class_="page-results results-page-thumb torpedo-container torpedo-container-xs")
    all_bambis = soup.find('div',class_="browse-content with-sidemenu") #先找到所有bambi作品所在的最大div
    #print(all_bambis) #输出该范围的所有内容

    #注意：csv转换区！
   # csv_file = open('BambiPageAll.csv','w',encoding="gbk",newline='')
   # writer = csv.writer(csv_file)

    #writer.writerow(["艺术家","热度"])#写入标题
    #csv转换块暂时结束

    #一下是在先前程序测试后排出标签异常页的更新
    
    #if( i!=9 and i!=16 and i!=17):
    for each_bambi in all_bambis.find_all('span',class_="info"):
            all_a_tag = each_bambi.find_all('a')
            all_hot_tag = each_bambi.find_all('span',class_="faves icon-faves")
            #bambi_artist = all_a_tag[1].text
            #bambi_hot = all_hot_tag[0].text
            #print("'a'标签个数=", len(all_a_tag))
            #print("热度所在标签",len(all_hot_tag))
            
            if(len(all_a_tag)==2 and len(all_hot_tag)==1):
                bambi_artist = all_a_tag[1].text
                bambi_hot = all_hot_tag[0].text
            #print(len(all_a_tag))#检测两个标签的数量是否符合平常数值
            #print(len(all_hot_tag))
                print('艺术家:{},热度:{}'.format(bambi_artist,bambi_hot))
                writer.writerow([bambi_artist,bambi_hot])

csv_file.close()
    #print("write_finished!")
# Out:
# 0
# 艺术家:xxcharlotteoxx,热度:86
# 艺术家:Sweet-Amy-Leah,热度:121
# 艺术家:shapudl,热度:112
# 艺术家:PurtyFlower,热度:75
# 艺术家:chacckco,热度:793
# 艺术家:megsmakesart,热度:99
# 艺术家:fighter-jet,热度:802
# 艺术家:BryanSyme,热度:147
# 艺术家:fidele,热度:61
# 艺术家:glimpen,热度:86
# 艺术家:skyknightnd,热度:73
# 艺术家:QueenOfGeeks,热度:122
# 艺术家:KerstinSchroeder,热度:355
# 艺术家:Gender-Ninja,热度:96
# 艺术家:RavenEvert,热度:99
# 艺术家:Velvet-Loz,热度:147
# 艺术家:JayAxer,热度:702
# 艺术家:nivardica,热度:63
# 艺术家:Macca4ever,热度:46
# 艺术家:AngelKittah,热度:156
# 艺术家:SonyaThough,热度:89
# 艺术家:tassanaburrfoot,热度:61
# 1
# 艺术家:hankypanky68,热度:31
# 艺术家:ArtofJonathanPowell,热度:1,343
# 艺术家:GakiRules,热度:79
# 艺术家:Lollypopsnbows,热度:67
# 艺术家:ReijiKageyama,热度:27
# 艺术家:akreon,热度:4,760
# 艺术家:Cibibot,热度:57
# 艺术家:sherwoodboy17,热度:124
# 艺术家:Jullelin,热度:97
# 艺术家:MasterChiefFox,热度:54
# 艺术家:Felinar,热度:307
# 艺术家:Sumo0172,热度:56
# 艺术家:Trounced,热度:935
# 艺术家:Mavuriku,热度:91
# 艺术家:sherwoodwhisper,热度:97
# 艺术家:Srduffman001,热度:51
# 艺术家:MajMajor,热度:94
# 艺术家:MoonyMina,热度:73
# 艺术家:Jenniej92,热度:195
# 艺术家:dragonfire1000,热度:53
# 2
# 艺术家:Ipun,热度:187
# 艺术家:FERNL,热度:149
# 艺术家:beckysmithh,热度:39
# 艺术家:augustc4,热度:1,642
# 艺术家:KippyTheGreat,热度:64
# 艺术家:Chenthooran,热度:56
# 艺术家:Tris-Marie,热度:37
# 艺术家:DrMistyTang,热度:5,333
# 艺术家:MsMergus,热度:79
# 艺术家:AbyssLeo,热度:83
# 艺术家:MoonyMina,热度:92
# 艺术家:cartoonprincessML,热度:37
# 艺术家:zillabean,热度:261
# 艺术家:DiveBomb5,热度:128
# 艺术家:Inked-Alpha,热度:60
# 艺术家:TwilightProwler,热度:258
# 艺术家:Felinar,热度:226
# 艺术家:NOMANSNODEAD,热度:51
# 艺术家:ukitakumuki,热度:962
# 艺术家:alucardserasfangirl,热度:120
# 3
# 艺术家:StallionDesigns,热度:38
# 艺术家:ShadowedImages,热度:21
# 艺术家:Brookestirr,热度:23
# 艺术家:Grigori77,热度:35
# 艺术家:Alena-Koshkar,热度:529
# 艺术家:deztyle,热度:347
# 艺术家:pitbullsaviour,热度:23
# 艺术家:diablo2003,热度:1,047
# 艺术家:Tris-Marie,热度:20
# 艺术家:jamesfoxbr,热度:63
# 艺术家:AlPendragon,热度:43
# 艺术家:ReallyReallyBigBang,热度:117
# 艺术家:synconi,热度:100
# 艺术家:wisahkecahk,热度:55
# 艺术家:LalaLottaAvatars,热度:9
# 艺术家:bibliodragon,热度:104
# 艺术家:FfarquharEngine,热度:57
# 艺术家:Golden-Dreams,热度:19
# 艺术家:josephinekazuki,热度:137
# 艺术家:Dean-Irvine,热度:36
# 艺术家:x12Rapunzelx,热度:62
# 艺术家:VinVagia,热度:64
# 4
# 艺术家:St-Pete,热度:126
# 艺术家:Lugnut1995,热度:89
# 艺术家:GramMoo,热度:38
# 艺术家:AniGami,热度:19
# 艺术家:MissAC333,热度:15
# 艺术家:starrlightstarbright,热度:274
# 艺术家:KessieLou,热度:79
# 艺术家:rikimaru1,热度:39
# 艺术家:LadyNorthstar,热度:651
# 艺术家:Alamarus,热度:31
# 艺术家:khalamithy,热度:19
# 艺术家:starrlightstarbright,热度:123
# 艺术家:SabakuNoTemari88,热度:78
# 艺术家:Colossvs6,热度:14
# 艺术家:starrlightstarbright,热度:78
# 艺术家:GlamourKat,热度:12
# 艺术家:starrlightstarbright,热度:92
# 艺术家:starrlightstarbright,热度:91
# 艺术家:starrlightstarbright,热度:89
# 艺术家:starrlightstarbright,热度:67
# 艺术家:starrlightstarbright,热度:70
# 艺术家:starrlightstarbright,热度:63
# 5
# 艺术家:Boneitis,热度:44
# 艺术家:billywallwork525,热度:37
# 艺术家:starrlightstarbright,热度:53
# 艺术家:starrlightstarbright,热度:52
# 艺术家:himichu,热度:74
# 艺术家:StallionDesigns,热度:52
# 艺术家:Justaminute,热度:78
# 艺术家:MojoJump,热度:34
# 艺术家:saldrome,热度:32
# 艺术家:Sooty-Bunnie,热度:15
# 艺术家:Snapai,热度:50
# 艺术家:ALicede,热度:70
# 艺术家:cmara,热度:52
# 艺术家:starrlightstarbright,热度:43
# 艺术家:starrlightstarbright,热度:14
# 艺术家:starrlightstarbright,热度:40
# 艺术家:starrlightstarbright,热度:38
# 艺术家:FERNL,热度:117
# 艺术家:starrlightstarbright,热度:40
# 艺术家:starrlightstarbright,热度:40
# 艺术家:starrlightstarbright,热度:38
# 艺术家:starrlightstarbright,热度:37
# 艺术家:MimiTheFox,热度:19
# 6
# 艺术家:starrlightstarbright,热度:32
# 艺术家:KillerLillers,热度:31
# 艺术家:XxSilentForcexX,热度:16
# 艺术家:starrlightstarbright,热度:29
# 艺术家:Sammaella,热度:61
# 艺术家:Pyrotactick,热度:17
# 艺术家:starrlightstarbright,热度:29
# 艺术家:starsandblueroses,热度:51
# 艺术家:starrlightstarbright,热度:26
# 艺术家:dentduloup,热度:94
# 艺术家:starrlightstarbright,热度:26
# 艺术家:starrlightstarbright,热度:26
# 艺术家:starrlightstarbright,热度:24
# 艺术家:Gamibrii,热度:14
# 艺术家:starrlightstarbright,热度:26
# 艺术家:DaveCarignan,热度:19
# 艺术家:starrlightstarbright,热度:22
# 艺术家:JavierOrlando,热度:40
# 艺术家:Flickward,热度:55
# 艺术家:Sunshiny-Disposition,热度:32
# 艺术家:Bambily,热度:31
# 艺术家:starfiregal92,热度:45
