# %%
#本部分调研搜索界面的第2页
#调用requetss包请求网页源代码
import requests
from bs4 import BeautifulSoup
from bs4 import element
import csv
#本次抽样百分之一，26份样品，1个页面
#本次直接爬取了从0到144页面的所有相应信息，将信息保存在csv格式文件之中

#以下是csv转换区，提前做好csv表格准备
csv_file = open('LadyAndTrampAll.csv','w',encoding="gbk",newline='')
writer = csv.writer(csv_file)
writer.writerow(["艺术家","热度"])#编辑表格中的标题

for i in range(0,7):
    print(i)#这里用来验证页数是否正常
    icount = i*24
    url = "https://www.deviantart.com/popular-all-time/?section=&global=1&q=Lady+and+the+Tramp&offset="+str(icount)
    response = requests.get(url)
    #print(response.content.decode('utf-8'))

    #将网页源代码保存到本地MyBambi.html文件中
    file_obj = open('MyLadyAll.html','w')
    file_obj.write(response.content.decode('utf-8'))
    file_obj.close()

    #从bs4引入数据提取工具BeautifulSoup
    from bs4 import BeautifulSoup
    file_obj = open('MyLadyAll.html','r')#以读方式打开MyBambi文件
    html = file_obj.read() #把文件的内容全部读出来并赋值给html变量
    file_obj.close()
    soup = BeautifulSoup(html,'html5lib')#html.parser,html5lib初始化BeautifulSoup，使用lxml有可能会有格式问题
    #print(soup)#输出BeautifulSoup转换后 的源代码内容

    #all_bambis = soup.find('div',class_="page-results results-page-thumb torpedo-container torpedo-container-xs")
    all_bambis = soup.find('div',class_="browse-content with-sidemenu") #先找到所有bambi作品所在的最大div
    #print(all_bambis) #输出该范围的所有内容

    #注意：csv转换区！
   # csv_file = open('BambiPageAll.csv','w',encoding="gbk",newline='')
   # writer = csv.writer(csv_file)

    #writer.writerow(["艺术家","热度"])#写入标题
    #csv转换块暂时结束
    
    #一下是在先前程序测试后排出标签异常页的更新
    
    #if(i!=27 and i!=39 and i!=66 and i!=97and i!=106 and i!=140):
    for each_bambi in all_bambis.find_all('span',class_="info"):
            all_a_tag = each_bambi.find_all('a')
            all_hot_tag = each_bambi.find_all('span',class_="faves icon-faves")
            bambi_artist = all_a_tag[1].text
            bambi_hot = all_hot_tag[0].text
            print('艺术家:{},热度:{}'.format(bambi_artist,bambi_hot))
            writer.writerow([bambi_artist,bambi_hot])

csv_file.close()
    #print("write_finished!")
# Out:
# 0
# 艺术家:chacckco,热度:1,940
# 艺术家:mitchie-v,热度:367
# 艺术家:Grinch-Layyla,热度:85
# 艺术家:SheltieWolf,热度:874
# 艺术家:greydeer2010,热度:140
# 艺术家:jimmyfromthemoon,热度:394
# 艺术家:princess-femi-stamps,热度:174
# 艺术家:PokeartKid,热度:175
# 艺术家:Strawberry-2110,热度:381
# 艺术家:MartijnPipoo,热度:195
# 艺术家:Ave606,热度:187
# 艺术家:Mareishon,热度:1,760
# 艺术家:mitchie-v,热度:178
# 艺术家:Dandric101,热度:151
# 艺术家:WrathOfReeses,热度:286
# 艺术家:lambini,热度:689
# 艺术家:pat-mcmichael,热度:2,086
# 艺术家:taranee9,热度:142
# 艺术家:Tora20,热度:550
# 艺术家:Rajacenna,热度:782
# 艺术家:Egretink,热度:212
# 1
# 艺术家:mrgoggles,热度:544
# 艺术家:Jose-Ramiro,热度:146
# 艺术家:mikriDeb,热度:159
# 艺术家:VexaTheKeybearer,热度:303
# 艺术家:Hyung86,热度:3,939
# 艺术家:Paola-Tosca,热度:307
# 艺术家:Cheyanne-Stinson,热度:106
# 艺术家:Katsuomangaka,热度:261
# 艺术家:s0alaina,热度:930
# 艺术家:DrMistyTang,热度:2,180
# 艺术家:WildSpiritWolf,热度:605
# 艺术家:JoyfulArtist21,热度:144
# 艺术家:raya2222,热度:79
# 艺术家:Picolo-kun,热度:2,894
# 艺术家:LucarioOcarina,热度:122
# 艺术家:HippocornDesigns,热度:170
# 艺术家:KT-JadeBlaze,热度:160
# 艺术家:nightwing1975,热度:300
# 艺术家:tigerfied,热度:60
# 艺术家:WildSpiritWolf,热度:571
# 艺术家:Tsuchan,热度:339
# 艺术家:Hyung86,热度:578
# 艺术家:snazzie-designz,热度:74
# 2
# 艺术家:1234LERT7Nan2,热度:133
# 艺术家:city-shuffle,热度:99
# 艺术家:MelodyNieves,热度:344
# 艺术家:princekido,热度:4,075
# 艺术家:TUWKA,热度:456
# 艺术家:TitanicGal1912,热度:569
# 艺术家:CarlosMota,热度:55
# 艺术家:Akili-Amethyst,热度:785
# 艺术家:Satsori,热度:465
# 艺术家:zora-iuga,热度:263
# 艺术家:salzraender,热度:287
# 艺术家:Arkay9,热度:78
# 艺术家:Hikasawr,热度:112
# 艺术家:Altairas,热度:123
# 艺术家:Maleficent84,热度:93
# 艺术家:TallyBaby13,热度:34
# 艺术家:XxIma-DreamerxX,热度:205
# 艺术家:RoxyFoxT,热度:149
# 艺术家:Amanda64,热度:111
# 艺术家:giadina96,热度:91
# 艺术家:Inspector97,热度:123
# 艺术家:ishaped,热度:360
# 艺术家:The-Paper-Pony,热度:156
# 3
# 艺术家:EHH123,热度:184
# 艺术家:TallyBaby13,热度:16
# 艺术家:PhillieCheesie,热度:86
# 艺术家:chacckco,热度:3,116
# 艺术家:Ravietta,热度:549
# 艺术家:cranberry--zombie,热度:217
# 艺术家:Jose-Ramiro,热度:75
# 艺术家:Koshi-Doshi,热度:100
# 艺术家:rebenke,热度:275
# 艺术家:Samscrapbook,热度:80
# 艺术家:xTrent968,热度:202
# 艺术家:GoldieRetriever,热度:52
# 艺术家:Dogasaur,热度:17
# 艺术家:Noiledluv,热度:150
# 艺术家:kaminene,热度:92
# 艺术家:AthosLuca,热度:55
# 艺术家:GinnyWeasley-13,热度:137
# 艺术家:MortenEng21,热度:67
# 艺术家:Blue-Fox,热度:314
# 艺术家:Rainbow-Moose,热度:61
# 艺术家:lockjavv,热度:21
# 艺术家:Anglesart,热度:99
# 4
# 艺术家:Honeysucle10,热度:251
# 艺术家:Verona7881,热度:318
# 艺术家:AnonymousLink,热度:100
# 艺术家:Maleficent84,热度:33
# 艺术家:owl-bones,热度:71
# 艺术家:Sardistri,热度:38
# 艺术家:FlareAndIcicle,热度:193
# 艺术家:GoldieRetriever,热度:148
# 艺术家:Cvy,热度:820
# 艺术家:JessieJames-1992,热度:91
# 艺术家:MizzieStarr,热度:67
# 艺术家:RoroZoro,热度:215
# 艺术家:dedkake,热度:31
# 艺术家:Nasuki100,热度:1,039
# 艺术家:dragonsrose0483,热度:66
# 艺术家:Raiilynezz,热度:352
# 艺术家:funnytime77,热度:96
# 艺术家:fireangel7485,热度:120
# 艺术家:Icecradle,热度:27
# 艺术家:IsBreaLiomCaife,热度:21
# 艺术家:vanillacoke-disney,热度:205
# 艺术家:MetalExveemon,热度:101
# 5
# 艺术家:Lucky978,热度:1,234
# 艺术家:Paola-Tosca,热度:92
# 艺术家:Aiyana-Kopa,热度:97
# 艺术家:ohara916,热度:148
# 艺术家:DoggieDiversity,热度:26
# 艺术家:TwilightProwler,热度:761
# 艺术家:DiablaVampire,热度:105
# 艺术家:TACOBELLABAE,热度:224
# 艺术家:EHH123,热度:122
# 艺术家:JuPMod,热度:300
# 艺术家:KostasKappa,热度:44
# 艺术家:MortenEng21,热度:70
# 艺术家:Shadowfollowed,热度:275
# 艺术家:CelticBotan,热度:205
# 艺术家:MortenEng21,热度:107
# 艺术家:scribblin,热度:27
# 艺术家:Oha,热度:1,309
# 艺术家:claramalka,热度:130
# 艺术家:Demonic-Pokeyfruit,热度:124
# 艺术家:bennixalice,热度:60
# 艺术家:claramalka,热度:241
# 艺术家:Ikuzram021,热度:69
# 艺术家:Eolewyn1010,热度:77
# 艺术家:Kamirah,热度:4,219
# 6
# 艺术家:Lady-Bleu,热度:73
# 艺术家:jeremiasch,热度:355
# 艺术家:acetea-san,热度:53
# 艺术家:accursedx,热度:46
# 艺术家:billywallwork525,热度:85
# 艺术家:freakyhedgehog,热度:79
# 艺术家:Firespirit7,热度:59
# 艺术家:Portentous-Progress,热度:57
# 艺术家:CrookedPictures,热度:43
# 艺术家:DianeAz,热度:73
# 艺术家:dorisdoris,热度:123
# 艺术家:DrMistyTang,热度:289
# 艺术家:edwardsuoh13,热度:68
# 艺术家:SilentArtist-A,热度:36
# 艺术家:equestrian10,热度:127
# 艺术家:naruto32,热度:113
# 艺术家:CaraLouKimba,热度:80
# 艺术家:Valvador,热度:164
# 艺术家:Mawnbak,热度:62
# 艺术家:Stephy09,热度:196
# 艺术家:MemorySoul,热度:36
