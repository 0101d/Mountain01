# %%
#本部分调研搜索界面的第2页
#调用requetss包请求网页源代码
import requests
from bs4 import BeautifulSoup
from bs4 import element
import csv
#本次抽样百分之一，47份样品，1个页面
#本次直接爬取了从0到144页面的所有相应信息，将信息保存在csv格式文件之中

#以下是csv转换区，提前做好csv表格准备
csv_file = open('ShereKhanAll.csv','w',encoding="gbk",newline='')
writer = csv.writer(csv_file)
writer.writerow(["艺术家","热度"])#编辑表格中的标题

for i in range(0,2):
    print(i)#这里用来验证页数是否正常
    icount = i*24
    url = "https://www.deviantart.com/popular-all-time/?section=&global=1&q=Shere+khan&offset="+str(icount)
    response = requests.get(url)
    #print(response.content.decode('utf-8'))

    #将网页源代码保存到本地MyBambi.html文件中
    file_obj = open('MyShereKhanAll.html','w')
    file_obj.write(response.content.decode('utf-8'))
    file_obj.close()

    #从bs4引入数据提取工具BeautifulSoup
    from bs4 import BeautifulSoup
    file_obj = open('MyShereKhanAll.html','r')#以读方式打开MyBambi文件
    html = file_obj.read() #把文件的内容全部读出来并赋值给html变量
    file_obj.close()
    soup = BeautifulSoup(html,'html5lib')#html.parser,html5lib初始化BeautifulSoup，使用lxml有可能会有格式问题
    #print(soup)#输出BeautifulSoup转换后 的源代码内容

    #all_bambis = soup.find('div',class_="page-results results-page-thumb torpedo-container torpedo-container-xs")
    all_bambis = soup.find('div',class_="browse-content with-sidemenu") #先找到所有bambi作品所在的最大div
    #print(all_bambis) #输出该范围的所有内容

    #注意：csv转换区！
   # csv_file = open('BambiPageAll.csv','w',encoding="gbk",newline='')
   # writer = csv.writer(csv_file)

    #writer.writerow(["艺术家","热度"])#写入标题
    #csv转换块暂时结束

    #一下是在先前程序测试后排出标签异常页的更新
    
    #if( i!=9 and i!=16 and i!=17):
    for each_bambi in all_bambis.find_all('span',class_="info"):
            all_a_tag = each_bambi.find_all('a')
            all_hot_tag = each_bambi.find_all('span',class_="faves icon-faves")
            #bambi_artist = all_a_tag[1].text
            #bambi_hot = all_hot_tag[0].text
            #print("'a'标签个数=", len(all_a_tag))
            #print("热度所在标签",len(all_hot_tag))
            
            if(len(all_a_tag)==2 and len(all_hot_tag)==1):
                bambi_artist = all_a_tag[1].text
                bambi_hot = all_hot_tag[0].text
            #print(len(all_a_tag))#检测两个标签的数量是否符合平常数值
            #print(len(all_hot_tag))
                print('艺术家:{},热度:{}'.format(bambi_artist,bambi_hot))
                writer.writerow([bambi_artist,bambi_hot])

csv_file.close()
    #print("write_finished!")
# Out:
# 0
# 艺术家:HaoAsakura16,热度:211
# 艺术家:MonicaMcClain,热度:356
# 艺术家:Valixy,热度:349
# 艺术家:FelonDog,热度:657
# 艺术家:J-e-J-e,热度:455
# 艺术家:kalizin,热度:104
# 艺术家:Grincha,热度:3,183
# 艺术家:Naure,热度:130
# 艺术家:jeorje90,热度:133
# 艺术家:husky50,热度:302
# 艺术家:Grincha,热度:1,277
# 艺术家:KarlaRuiz,热度:168
# 艺术家:GoldenDaniel,热度:285
# 艺术家:pmaestro,热度:259
# 艺术家:kenket,热度:794
# 艺术家:Felinar,热度:490
# 艺术家:freakyfir,热度:406
# 艺术家:Lucky978,热度:524
# 艺术家:heatherbunny,热度:103
# 艺术家:TheRaineDrop,热度:527
# 艺术家:The-PirateQueen,热度:524
# 艺术家:Kobb,热度:255
# 艺术家:DavidGFerrero,热度:127
# 1
# 艺术家:VVraith,热度:34
# 艺术家:cloudrat,热度:1,206
# 艺术家:MintyMaguire,热度:152
# 艺术家:The-PirateQueen,热度:796
# 艺术家:scarypet,热度:1,005
# 艺术家:Carliihde,热度:190
# 艺术家:Mayshha,热度:268
# 艺术家:LionChanti,热度:40
# 艺术家:avispaneitor,热度:101
# 艺术家:Sharzn,热度:15
# 艺术家:Hyung86,热度:2,705
# 艺术家:SophieXSmith,热度:134
# 艺术家:kiki-doodle,热度:352
# 艺术家:ButtonsMaker,热度:84
# 艺术家:michaelkutsche,热度:1,518
# 艺术家:The-PirateQueen,热度:381
# 艺术家:MetalExveemon,热度:91
# 艺术家:101dalfan,热度:27
# 艺术家:Jose-Ramiro,热度:80
# 艺术家:NostalgicChills,热度:377
# 艺术家:plutoplus1,热度:93
# 艺术家:TussenSessan,热度:135
# 艺术家:wanderer1988,热度:80
