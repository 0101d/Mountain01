# %%
#本部分调研搜索界面的第2页
#调用requetss包请求网页源代码
import requests
from bs4 import BeautifulSoup
from bs4 import element
import csv
#本次抽样百分之一，244份样品，11个页面
#本次直接爬取了从0到144页面的所有相应信息，将信息保存在csv格式文件之中

#以下是csv转换区，提前做好csv表格准备
csv_file = open('DumboAll.csv','w',encoding="gbk",newline='')
writer = csv.writer(csv_file)
writer.writerow(["艺术家","热度"])#编辑表格中的标题

for i in range(0,11):
    print(i)#这里用来验证页数是否正常
    icount = i*24
    url = "https://www.deviantart.com/popular-all-time/?section=&global=1&q=Dumbo&offset="+str(icount)
    response = requests.get(url)
    #print(response.content.decode('utf-8'))

    #将网页源代码保存到本地MyBambi.html文件中
    file_obj = open('MyDumboAll.html','w')
    file_obj.write(response.content.decode('utf-8'))
    file_obj.close()

    #从bs4引入数据提取工具BeautifulSoup
    from bs4 import BeautifulSoup
    file_obj = open('MyDumboAll.html','r')#以读方式打开MyBambi文件
    html = file_obj.read() #把文件的内容全部读出来并赋值给html变量
    file_obj.close()
    soup = BeautifulSoup(html,'html5lib')#html.parser,html5lib初始化BeautifulSoup，使用lxml有可能会有格式问题
    #print(soup)#输出BeautifulSoup转换后 的源代码内容

    #all_bambis = soup.find('div',class_="page-results results-page-thumb torpedo-container torpedo-container-xs")
    all_bambis = soup.find('div',class_="browse-content with-sidemenu") #先找到所有bambi作品所在的最大div
    #print(all_bambis) #输出该范围的所有内容

    #注意：csv转换区！
   # csv_file = open('BambiPageAll.csv','w',encoding="gbk",newline='')
   # writer = csv.writer(csv_file)

    #writer.writerow(["艺术家","热度"])#写入标题
    #csv转换块暂时结束

    #一下是在先前程序测试后排出标签异常页的更新
    
    #if( i!=9 and i!=16 and i!=17):
    for each_bambi in all_bambis.find_all('span',class_="info"):
            all_a_tag = each_bambi.find_all('a')
            all_hot_tag = each_bambi.find_all('span',class_="faves icon-faves")
            #bambi_artist = all_a_tag[1].text
            #bambi_hot = all_hot_tag[0].text
            #print("'a'标签个数=", len(all_a_tag))
            #print("热度所在标签",len(all_hot_tag))
            
            if(len(all_a_tag)==2 and len(all_hot_tag)==1):
                bambi_artist = all_a_tag[1].text
                bambi_hot = all_hot_tag[0].text
            #print(len(all_a_tag))#检测两个标签的数量是否符合平常数值
            #print(len(all_hot_tag))
                print('艺术家:{},热度:{}'.format(bambi_artist,bambi_hot))
                writer.writerow([bambi_artist,bambi_hot])

csv_file.close()
    #print("write_finished!")
# Out:
# 0
# 艺术家:Tallychyck,热度:269
# 艺术家:Wilsonlym,热度:274
# 艺术家:xXKaWaii-RuKiaXx,热度:152
# 艺术家:Man0uk,热度:430
# 艺术家:KerstinSchroeder,热度:174
# 艺术家:ladyjudina,热度:112
# 艺术家:Chatelier,热度:91
# 艺术家:paperfetish,热度:152
# 艺术家:greciiagzz,热度:94
# 艺术家:BlackCyanide-fr,热度:121
# 艺术家:RavenEvert,热度:97
# 艺术家:Daphne8,热度:223
# 艺术家:29steph5,热度:94
# 艺术家:sinsenor,热度:553
# 艺术家:Vinicius040598,热度:38
# 艺术家:pikaole,热度:171
# 艺术家:Sephiroth-Art,热度:96
# 艺术家:Citron--Vert,热度:15
# 艺术家:da-bu-di-bu-da,热度:117
# 艺术家:Maleficent84,热度:77
# 艺术家:QueenGlitterbutt,热度:60
# 艺术家:wisahkecahk,热度:47
# 艺术家:fredvegerano,热度:124
# 艺术家:nushhhhhh,热度:50
# 艺术家:RavenEvert,热度:35
# 艺术家:ladyjudina,热度:77
# 艺术家:KittyJewelpet78,热度:25
# 艺术家:Citron--Vert,热度:49
# 艺术家:Santani,热度:9,667
# 艺术家:hybel,热度:84
# 艺术家:Doreeree,热度:95
# 艺术家:michaelkutsche,热度:1,040
# 艺术家:mintmovi3,热度:42
# 5
# 艺术家:mintmovi3,热度:35
# 艺术家:nEVEr-mor,热度:532
# 艺术家:RariJacks,热度:135
# 艺术家:Blaze-On-Fire,热度:36
# 艺术家:cypherx,热度:1,527
# 艺术家:Spirit-woods,热度:58
# 艺术家:morphinetears36,热度:40
# 艺术家:Gumbah,热度:35
# 艺术家:FrozenFeather,热度:113
# 艺术家:AnimationValley,热度:25
# 艺术家:cakecrumbs,热度:122
# 艺术家:Maleficent84,热度:68
# 艺术家:griffsnuff,热度:479
# 艺术家:jebens1,热度:54
# 艺术家:DragonsAndBeasties,热度:422
# 艺术家:MKLier,热度:64
# 艺术家:YumeSamasLover,热度:65
# 艺术家:GameGeeksDeviant,热度:39
# 艺术家:philosophyfox,热度:171
# 艺术家:mintmovi3,热度:25
# 6
# 艺术家:JenrenG,热度:109
# 艺术家:RavenEvert,热度:111
# 艺术家:rebenke,热度:80
# 艺术家:Lelpel,热度:39
# 艺术家:AfroOtaku917,热度:59
# 艺术家:DeedNoxious,热度:48
# 艺术家:AnimationValley,热度:18
# 艺术家:elirain,热度:41
# 艺术家:AllTimeScream,热度:14
# 艺术家:Sketch-Shepherd,热度:31
# 艺术家:MorkelErasmus,热度:133
# 艺术家:MoonyMina,热度:63
# 艺术家:TwilightProwler,热度:65
# 艺术家:TwilightProwler,热度:210
# 艺术家:GameGeeksDeviant,热度:29
# 艺术家:terronsitodasucar,热度:48
# 艺术家:FrozenFeather,热度:69
# 艺术家:theillustratedrat,热度:53
# 艺术家:Natan-Ferri,热度:37
# 艺术家:GalaticKaiju,热度:37
# 艺术家:GACHY-CELTA,热度:36
# 艺术家:camila-bunny,热度:126
# 7
# 艺术家:AzureAngel2ihrs,热度:18
# 艺术家:philosophyfox,热度:169
# 艺术家:Koniimelia,热度:49
# 艺术家:RyanBrony765,热度:30
# 艺术家:Citron--Vert,热度:9
# 艺术家:seles66,热度:71
# 艺术家:THEoriginalADAM,热度:32
# 艺术家:RetroCharo,热度:56
# 艺术家:ChrisAndCompany,热度:99
# 艺术家:anthero,热度:50
# 艺术家:helloprettybirdie,热度:43
# 艺术家:BluTaiger,热度:46
# 艺术家:cmara,热度:56
# 艺术家:Mega-Shonen-One-64,热度:44
# 艺术家:LynxGriffin,热度:78
# 艺术家:ono-mono,热度:74
# 艺术家:JoshuaOrro,热度:42
# 艺术家:SithVampireMaster27,热度:35
# 艺术家:Tinyhuff,热度:56
# 艺术家:MicroPixels,热度:41
# 艺术家:mayumi-loves-sora,热度:61
# 艺术家:Camo-Flauge,热度:33
# 艺术家:Weischede,热度:41
# 艺术家:NVillustration,热度:172
# 8
# 艺术家:szorny-stock,热度:22
# 艺术家:mintmovi3,热度:22
# 艺术家:brazilianferalcat,热度:48
# 艺术家:Budunk,热度:28
# 艺术家:DragonsAndBeasties,热度:93
# 艺术家:philosophyfox,热度:86
# 艺术家:Camo-Flauge,热度:29
# 艺术家:KitLightning,热度:8
# 艺术家:philosophyfox,热度:78
# 艺术家:LostMustard,热度:23
# 艺术家:SillyNate,热度:39
# 艺术家:garyjsmith,热度:98
# 艺术家:AverageJoeArtwork,热度:45
# 艺术家:AndrewMcIntoshArt,热度:104
# 艺术家:philosophyfox,热度:121
# 艺术家:MiketheElephantBrony,热度:18
# 艺术家:WesleyAbram,热度:127
# 艺术家:amyosaurus-rex,热度:25
# 艺术家:Oakiel,热度:450
# 艺术家:hontor,热度:275
# 艺术家:JuanpaDraws,热度:30
# 艺术家:Santani,热度:345
# 艺术家:LynxGriffin,热度:63
# 艺术家:AverageJoeArtwork,热度:41
# 9
# 艺术家:BlueSuperSonic,热度:73
# 艺术家:Darkoshen,热度:200
# 艺术家:larissakathryn95,热度:27
# 艺术家:angelratdesigns,热度:22
# 艺术家:xxhimeguts,热度:239
# 艺术家:philosophyfox,热度:75
# 艺术家:hontor,热度:200
# 艺术家:alexartchanimte7,热度:13
# 艺术家:Trillatia,热度:51
# 艺术家:michaelkutsche,热度:161
# 艺术家:philosophyfox,热度:65
# 艺术家:Cryptid-Creations,热度:3,742
# 艺术家:superjay15,热度:54
# 艺术家:magur,热度:62
# 艺术家:Kayas-Kosmos,热度:49
# 艺术家:peachysoft,热度:41
# 艺术家:KristineButterfly,热度:29
# 艺术家:JasonKoons,热度:58
# 艺术家:zenoasis,热度:8
# 艺术家:Sunshiny-Disposition,热度:30
# 艺术家:ValerieGallery,热度:63
# 艺术家:honeysunshinetw,热度:38
# 艺术家:szorny-stock,热度:11
# 10
# 艺术家:JasonKoons,热度:60
# 艺术家:GameGeeksDeviant,热度:20
# 艺术家:shininginthedarkness,热度:14
# 艺术家:KrazyRatLady,热度:68
# 艺术家:Citron--Vert,热度:51
# 艺术家:choose2bgr8,热度:39
# 艺术家:Valforwing,热度:35
# 艺术家:xavierrey,热度:72
# 艺术家:GameGeeksDeviant,热度:45
# 艺术家:Weischede,热度:47
# 艺术家:Jonathan-Flash,热度:68
# 艺术家:philosophyfox,热度:94
# 艺术家:Juice183,热度:39
# 艺术家:gissele365,热度:51
# 艺术家:Fuye,热度:98
# 艺术家:Wangler,热度:20
# 艺术家:IrisInsanitie,热度:31
# 艺术家:hirokono,热度:21
# 艺术家:Gadani13,热度:28
# 艺术家:Blossom525,热度:25
# 艺术家:cmara,热度:46
# 艺术家:Annushkka,热度:11
